# %% [markdown]
# <a href="https://colab.research.google.com/github/Arqamansari23/NLP/blob/main/Content_Based_Recommendation_System_Using_Huggingface_Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # **Reading The data**

# %%
df=pd.read_csv('/content/drive/MyDrive/NLP/anime.csv')

# %%
df.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
df.isna().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %% [markdown]
# # Combining All columns And make Single Feature called Description

# %%
df['description']=df['name']+' '+ df['genre']+" " 'ratinngs:'+df['rating'].astype(str)+" " 'episodes:'+df['episodes']

# %%
df.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members                                        description
# 0   200630  Kimi no Na wa. Drama, Romance, School, Superna...
# 1   793665  Fullmetal Alchemist: Brotherhood Action, Adven...
# ...

# %%
df['description'][0]
# Out:
# 'Kimi no Na wa. Drama, Romance, School, Supernatural ratinngs:9.37 episodes:1'

# %% [markdown]
# # About sentence-transformers/all-MiniLM-L6-v2 Model

# %% [markdown]
# *   This is a sentence-transformers model: It maps sentences & paragraphs to a 384 dimensional dense vector space and can be used for tasks like clustering or semantic search.
#
# *   it converts One sentence into one Embedding vector
#
# *   No need For Tokanization
#
# *   No need for padding

# %% [markdown]
# # importing sentence-transformers/all-MiniLM-L6-v2 Model

# %%
# !pip install -U sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.1/249.1 kB 4.4 MB/s eta 0:00:00
# ...

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# # Generating Embeddings

# %%
anime_embeddings = model.encode(df['description'].tolist())

# %% [markdown]
# # Cosine Similarity Function

# %%
from sklearn.metrics.pairwise import cosine_similarity

def get_recommendations(query, embeddings, df, top_n=5):
    query_embedding = model.encode([query])
    similarities = cosine_similarity(query_embedding, embeddings)
    top_indices = similarities[0].argsort()[-top_n:][::-1]
    return df.iloc[top_indices]

# %% [markdown]
# # recommendations

# %%
query = "horror movie"
recommendations = get_recommendations(query, anime_embeddings, df)

# %%
recommendations
# Out:
#       anime_id                                  name  \
# 7815     33042  Zonmi-chan: Halloween☆Special Movie!
# 2136     13677          Ao no Exorcist Movie Special
# 9535      7751                Midnight Horror School
# 7986     11869                          Bloody Night
# 7987     20811                      Maid of the Dead
#
#                                               genre     type episodes  rating  \
# 7815                                 Comedy, Horror      ONA        1    4.94
# 2136                                 Comedy, Parody  Special        1    7.34
# 9535                                         Comedy       TV       52    6.90
# 7986  Horror, Psychological, Supernatural, Thriller      ONA        1    4.26
# 7987                                 Comedy, Horror      ONA        1    4.26
#
#       members                                        description
# 7815      276  Zonmi-chan: Halloween☆Special Movie! Comedy, H...
# ...
